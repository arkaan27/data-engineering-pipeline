# %%
import boto3
import wandb
import pandas as pd
from pathlib import Path
from collections import defaultdict

# %%
# Creating a run and using the downloaded data
run = wandb.init(project="data-engineering", group="EDA", save_code=True)
data = wandb.use_artifact("raw_data:latest").download()
# Out:
# Finishing last run (ID:24vailj4) before initializing another...
# <br/>Waiting for W&B process to finish, PID 6457<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/mnt/d/data-engineering-pipeline/src/components/EDA/wandb/run-20220306_192010-24vailj4/logs/debug.log</code>
# Find internal logs for this run at: <code>/mnt/d/data-engineering-pipeline/src/components/EDA/wandb/run-20220306_192010-24vailj4/logs/debug-internal.log</code>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">elated-galaxy-17</strong>: <a href="https://wandb.ai/arkaan27/data-engineering/runs/24vailj4" target="_blank">https://wandb.ai/arkaan27/data-engineering/runs/24vailj4</a><br/>
# ...Successfully finished last run (ID:24vailj4). Initializing new run:<br/><br/>
# wandb: wandb version 0.12.11 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">crimson-bird-18</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/arkaan27/data-engineering" target="_blank">https://wandb.ai/arkaan27/data-engineering</a><br/>
#                 Run page: <a href="https://wandb.ai/arkaan27/data-engineering/runs/2wxclaai" target="_blank">https://wandb.ai/arkaan27/data-engineering/runs/2wxclaai</a><br/>
#                 Run data is saved locally in <code>/mnt/d/data-engineering-pipeline/src/components/EDA/wandb/run-20220306_192344-2wxclaai</code><br/><br/>
# wandb: Downloading large artifact raw_data:latest, 170.82MB. 79 files... Done. 0:0:0

# %%
os.getcwd()
data=os.path.join(os.getcwd(),"artifacts/raw_data:v0")
data
data="./artifacts/raw_data:v0"

# %%
import os
import json
from pathlib import Path
from collections import defaultdict

# Creating output dir for the processed data & converting it to posix type
output_dir= "processed_data"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    
# Looping over files    
for root, dirs, files in os.walk(data):
    for file in files:
        print(file)
        with open(file) as f:
            extracted_data = json.load(f)
            entries = extracted_data["entry"]
# Out:
# Aaron697_Dickens475_8c95253e-8ee8-9ae8-6d40-021d702dc78e.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [125], in <cell line: 12>()
#      13 for file in files:
#      14     print(file)
# ---> 15     with open(file) as f:
#      16         extracted_data = json.load(f)
#      17         entries = extracted_data["entry"]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Aaron697_Dickens475_8c95253e-8ee8-9ae8-6d40-021d702dc78e.json'

# %%
with open(file,mode='r') as f:
        
            # Extracting all the entries of the file
            extracted_data = json.load(f)
            entries = extracted_data["entry"]
        
            # Creating set & dictionary for each file
            resource_types = set()
            entry_resources = defaultdict(list)
        
            # Extracting data to dictionary based on resource type for each file
            for resource in entries:
                resource_type = resource["resource"]["resourceType"]
                resource_types.add(resource_type)
                resource_file_path = output_dir +"/"+ f"{resource_type}.json"
                entry_resources[resource_file_path].append(resource)
            
        
            for resource_file_path, resources in entry_resources.items():
                if os.path.exists(resource_file_path):
                    #Getting existing records of each resource of each file
                    with open(resource_file_path,mode='r') as i:
                        contents = json.load(i)
                
                    contents.extend(resources)
                else:
                    contents = resources
                
                # save it to disk
                with open(resource_file_path,mode="w") as j:
                    json.dump(contents, j
# Out:
#   Input In [122]
#     json.dump(contents, j
#                          ^
# SyntaxError: unexpected EOF while parsing

# %%
entries
# Out:
# [{'fullUrl': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#   'resource': {'resourceType': 'Patient',
#    'id': '8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#    'text': {'status': 'generated',
#     'div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: master-branch-latest\n .   Person seed: 8886041252665297312  Population seed: 13235</div>'},
#    'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#      'extension': [{'url': 'ombCategory',
#        'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#         'code': '2106-3',
#         'display': 'White'}},
#       {'url': 'text', 'valueString': 'White'}]},
#     {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#      'extension': [{'url': 'ombCategory',
#        'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#         'code': '2186-5',
#         'display': 'Not Hispanic or Latino'}},
#       {'url': 'text', 'valueString': 'Not Hispanic or Latino'}]},
#     {'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName',
#      'valueString': 'Holley125 Champlin946'},
#     {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex',
#      'valueCode': 'M'},
#     {'url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace',
#      'valueAddress': {'city': 'Barnstable',
#       'state': 'Massachusetts',
#       'country': 'US'}},
#     {'url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years',
#      'valueDecimal': 0.05826471038258488},
#     {'url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years',
#      'valueDecimal': 52.94173528961741}],
#    'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#      'value': '8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR',
#         'display': 'Medical Record Number'}],
#       'text': 'Medical Record Number'},
#      'system': 'http://hospital.smarthealthit.org',
#      'value': '8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'SS',
#         'display': 'Social Security Number'}],
#       'text': 'Social Security Number'},
#      'system': 'http://hl7.org/fhir/sid/us-ssn',
#      'value': '999-86-2571'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'DL',
#         'display': "Driver's License"}],
#       'text': "Driver's License"},
#      'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#      'value': 'S99949530'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'PPN',
#         'display': 'Passport Number'}],
#       'text': 'Passport Number'},
#      'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#      'value': 'X67249552X'}],
#    'name': [{'use': 'official',
#      'family': 'Dickens475',
#      'given': ['Aaron697'],
#      'prefix': ['Mr.']}],
#    'telecom': [{'system': 'phone', 'value': '555-152-6034', 'use': 'home'}],
#    'gender': 'male',
#    'birthDate': '1944-08-28',
#    'deceasedDateTime': '1998-08-15T13:05:53+01:00',
#    'address': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/geolocation',
#        'extension': [{'url': 'latitude', 'valueDecimal': 42.13509612101196},
#         {'url': 'longitude', 'valueDecimal': -71.94977170576706}]}],
#      'line': ['859 Altenwerth Run Unit 88'],
#      'city': 'Charlton',
#      'state': 'MA',
#      'country': 'US'}],
#    'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus',
#       'code': 'M',
#       'display': 'M'}],
#     'text': 'M'},
#    'multipleBirthBoolean': False,
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English'}],
#       'text': 'English'}}]},
#   'request': {'method': 'POST', 'url': 'Patient'}},
#  {'fullUrl': 'urn:uuid:4dbc90e0-b7b2-482c-24af-1405654e59ae',
#   'resource': {'resourceType': 'Encounter',
#    'id': '4dbc90e0-b7b2-482c-24af-1405654e59ae',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter']},
#    'identifier': [{'use': 'official',
#      'system': 'https://github.com/synthetichealth/synthea',
#      'value': '4dbc90e0-b7b2-482c-24af-1405654e59ae'}],
#    'status': 'finished',
#    'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode',
#     'code': 'AMB'},
#    'type': [{'coding': [{'system': 'http://snomed.info/sct',
#        'code': '162673000',
#        'display': 'General examination of patient (procedure)'}],
#      'text': 'General examination of patient (procedure)'}],
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#     'display': 'Mr. Aaron697 Dickens475'},
#    'participant': [{'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-ParticipationType',
#          'code': 'PPRF',
#          'display': 'primary performer'}],
#        'text': 'primary performer'}],
#      'period': {'start': '1962-10-22T03:00:18+01:00',
#       'end': '1962-10-22T03:15:18+01:00'},
#      'individual': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#       'display': 'Dr. Wilmer32 Heidenreich818'}}],
#    'period': {'start': '1962-10-22T03:00:18+01:00',
#     'end': '1962-10-22T03:15:18+01:00'},
#    'location': [{'location': {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|08770baf-f5e6-3a1a-af4f-1d8be70df56f',
#       'display': 'MASS LUNG AND ALLERGY PC'}}],
#    'serviceProvider': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#     'display': 'MASS LUNG AND ALLERGY PC'}},
#   'request': {'method': 'POST', 'url': 'Encounter'}},
#  {'fullUrl': 'urn:uuid:2b9b5daf-ef78-63c7-3edc-cfc0a209eee0',
#   'resource': {'resourceType': 'Condition',
#    'id': '2b9b5daf-ef78-63c7-3edc-cfc0a209eee0',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition']},
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#        'code': 'encounter-diagnosis',
#        'display': 'Encounter Diagnosis'}]}],
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '224299000',
#       'display': 'Received higher education (finding)'}],
#     'text': 'Received higher education (finding)'},
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'encounter': {'reference': 'urn:uuid:4dbc90e0-b7b2-482c-24af-1405654e59ae'},
#    'onsetDateTime': '1962-10-22T03:50:09+01:00',
#    'recordedDate': '1962-10-22T03:50:09+01:00'},
#   'request': {'method': 'POST', 'url': 'Condition'}},
#  {'fullUrl': 'urn:uuid:b6487994-9b3f-7b3c-6e2d-feba134129f9',
#   'resource': {'resourceType': 'Condition',
#    'id': 'b6487994-9b3f-7b3c-6e2d-feba134129f9',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition']},
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#        'code': 'encounter-diagnosis',
#        'display': 'Encounter Diagnosis'}]}],
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '713458007',
#       'display': 'Lack of access to transportation (finding)'}],
#     'text': 'Lack of access to transportation (finding)'},
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'encounter': {'reference': 'urn:uuid:4dbc90e0-b7b2-482c-24af-1405654e59ae'},
#    'onsetDateTime': '1962-10-22T03:50:09+01:00',
#    'recordedDate': '1962-10-22T03:50:09+01:00'},
#   'request': {'method': 'POST', 'url': 'Condition'}},
#  {'fullUrl': 'urn:uuid:f76535a7-ac06-3e3c-d0a3-7285fb4c8dd8',
#   'resource': {'resourceType': 'DiagnosticReport',
#    'id': 'f76535a7-ac06-3e3c-d0a3-7285fb4c8dd8',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note']},
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://loinc.org',
#        'code': '34117-2',
#        'display': 'History and physical note'},
#       {'system': 'http://loinc.org',
#        'code': '51847-2',
#        'display': 'Evaluation+Plan note'}]}],
#    'code': {'coding': [{'system': 'http://loinc.org',
#       'code': '34117-2',
#       'display': 'History and physical note'},
#      {'system': 'http://loinc.org',
#       'code': '51847-2',
#       'display': 'Evaluation+Plan note'}]},
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'encounter': {'reference': 'urn:uuid:4dbc90e0-b7b2-482c-24af-1405654e59ae'},
#    'effectiveDateTime': '1962-10-22T03:00:18+01:00',
#    'issued': '1962-10-22T03:00:18.291+01:00',
#    'performer': [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#      'display': 'Dr. Wilmer32 Heidenreich818'}],
#    'presentedForm': [{'contentType': 'text/plain; charset=utf-8',
#      'data': '...'}]},
#   'request': {'method': 'POST', 'url': 'DiagnosticReport'}},
#  {'fullUrl': 'urn:uuid:e3cee541-d578-8b34-d729-3788b4380e40',
#   'resource': {'resourceType': 'DocumentReference',
#    'id': 'e3cee541-d578-8b34-d729-3788b4380e40',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-documentreference']},
#    'identifier': [{'system': 'urn:ietf:rfc:3986',
#      'value': 'urn:uuid:f76535a7-ac06-3e3c-d0a3-7285fb4c8dd8'}],
#    'status': 'superseded',
#    'type': {'coding': [{'system': 'http://loinc.org',
#       'code': '34117-2',
#       'display': 'History and physical note'},
#      {'system': 'http://loinc.org',
#       'code': '51847-2',
#       'display': 'Evaluation+Plan note'}]},
#    'category': [{'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category',
#        'code': 'clinical-note',
#        'display': 'Clinical Note'}]}],
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'date': '1962-10-22T03:00:18.291+01:00',
#    'author': [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#      'display': 'Dr. Wilmer32 Heidenreich818'}],
#    'custodian': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'content': [{'attachment': {'contentType': 'text/plain; charset=utf-8',
#       'data': '...'},
#      'format': {'system': 'http://ihe.net/fhir/ValueSet/IHE.FormatCode.codesystem',
#       'code': 'urn:ihe:iti:xds:2017:mimeTypeSufficient',
#       'display': 'mimeType Sufficient'}}],
#    'context': {'encounter': [{'reference': 'urn:uuid:4dbc90e0-b7b2-482c-24af-1405654e59ae'}],
#     'period': {'start': '1962-10-22T03:00:18+01:00',
#      'end': '1962-10-22T03:15:18+01:00'}}},
#   'request': {'method': 'POST', 'url': 'DocumentReference'}},
#  {'fullUrl': 'urn:uuid:0121fe66-58dc-78af-0323-6c8702d9d1db',
#   'resource': {'resourceType': 'Claim',
#    'id': '0121fe66-58dc-78af-0323-6c8702d9d1db',
#    'status': 'active',
#    'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/claim-type',
#       'code': 'institutional'}]},
#    'use': 'claim',
#    'patient': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#     'display': 'Aaron697 Dickens475'},
#    'billablePeriod': {'start': '1962-10-22T03:00:18+01:00',
#     'end': '1962-10-22T03:15:18+01:00'},
#    'created': '1962-10-22T03:15:18+01:00',
#    'provider': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'priority': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/processpriority',
#       'code': 'normal'}]},
#    'facility': {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|08770baf-f5e6-3a1a-af4f-1d8be70df56f',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'diagnosis': [{'sequence': 1,
#      'diagnosisReference': {'reference': 'urn:uuid:2b9b5daf-ef78-63c7-3edc-cfc0a209eee0'}},
#     {'sequence': 2,
#      'diagnosisReference': {'reference': 'urn:uuid:b6487994-9b3f-7b3c-6e2d-feba134129f9'}}],
#    'insurance': [{'sequence': 1,
#      'focal': True,
#      'coverage': {'display': 'NO_INSURANCE'}}],
#    'item': [{'sequence': 1,
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '162673000',
#         'display': 'General examination of patient (procedure)'}],
#       'text': 'General examination of patient (procedure)'},
#      'encounter': [{'reference': 'urn:uuid:4dbc90e0-b7b2-482c-24af-1405654e59ae'}]},
#     {'sequence': 2,
#      'diagnosisSequence': [1],
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '224299000',
#         'display': 'Received higher education (finding)'}],
#       'text': 'Received higher education (finding)'}},
#     {'sequence': 3,
#      'diagnosisSequence': [2],
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '713458007',
#         'display': 'Lack of access to transportation (finding)'}],
#       'text': 'Lack of access to transportation (finding)'}}],
#    'total': {'value': 786.3299999999999, 'currency': 'USD'}},
#   'request': {'method': 'POST', 'url': 'Claim'}},
#  {'fullUrl': 'urn:uuid:8c6a4d7d-8e7c-10f8-9a38-7f7a42049080',
#   'resource': {'resourceType': 'ExplanationOfBenefit',
#    'id': '8c6a4d7d-8e7c-10f8-9a38-7f7a42049080',
#    'contained': [{'resourceType': 'ServiceRequest',
#      'id': 'referral',
#      'status': 'completed',
#      'intent': 'order',
#      'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#      'requester': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519'},
#      'performer': [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519'}]},
#     {'resourceType': 'Coverage',
#      'id': 'coverage',
#      'status': 'active',
#      'type': {'text': 'NO_INSURANCE'},
#      'beneficiary': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#      'payor': [{'display': 'NO_INSURANCE'}]}],
#    'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#      'value': '0121fe66-58dc-78af-0323-6c8702d9d1db'},
#     {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#      'value': '99999999999'}],
#    'status': 'active',
#    'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/claim-type',
#       'code': 'institutional'}]},
#    'use': 'claim',
#    'patient': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'billablePeriod': {'start': '1962-10-22T03:15:18+01:00',
#     'end': '1963-10-22T03:15:18+01:00'},
#    'created': '1962-10-22T03:15:18+01:00',
#    'insurer': {'display': 'NO_INSURANCE'},
#    'provider': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519'},
#    'referral': {'reference': '#referral'},
#    'facility': {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|08770baf-f5e6-3a1a-af4f-1d8be70df56f',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'claim': {'reference': 'urn:uuid:0121fe66-58dc-78af-0323-6c8702d9d1db'},
#    'outcome': 'complete',
#    'careTeam': [{'sequence': 1,
#      'provider': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519'},
#      'role': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/claimcareteamrole',
#         'code': 'primary',
#         'display': 'Primary Care Practitioner'}]}}],
#    'diagnosis': [{'sequence': 1,
#      'diagnosisReference': {'reference': 'urn:uuid:2b9b5daf-ef78-63c7-3edc-cfc0a209eee0'},
#      'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-diagnosistype',
#          'code': 'principal'}]}]},
#     {'sequence': 2,
#      'diagnosisReference': {'reference': 'urn:uuid:b6487994-9b3f-7b3c-6e2d-feba134129f9'},
#      'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-diagnosistype',
#          'code': 'principal'}]}]}],
#    'insurance': [{'focal': True,
#      'coverage': {'reference': '#coverage', 'display': 'NO_INSURANCE'}}],
#    'item': [{'sequence': 1,
#      'category': {'coding': [{'system': 'https://bluebutton.cms.gov/resources/variables/line_cms_type_srvc_cd',
#         'code': '1',
#         'display': 'Medical care'}]},
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '162673000',
#         'display': 'General examination of patient (procedure)'}],
#       'text': 'General examination of patient (procedure)'},
#      'servicedPeriod': {'start': '1962-10-22T03:00:18+01:00',
#       'end': '1962-10-22T03:15:18+01:00'},
#      'locationCodeableConcept': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-serviceplace',
#         'code': '19',
#         'display': 'Off Campus-Outpatient Hospital'}]},
#      'encounter': [{'reference': 'urn:uuid:4dbc90e0-b7b2-482c-24af-1405654e59ae'}]},
#     {'sequence': 2,
#      'diagnosisSequence': [1],
#      'category': {'coding': [{'system': 'https://bluebutton.cms.gov/resources/variables/line_cms_type_srvc_cd',
#         'code': '1',
#         'display': 'Medical care'}]},
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '224299000',
#         'display': 'Received higher education (finding)'}],
#       'text': 'Received higher education (finding)'},
#      'servicedPeriod': {'start': '1962-10-22T03:00:18+01:00',
#       'end': '1962-10-22T03:15:18+01:00'},
#      'locationCodeableConcept': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-serviceplace',
#         'code': '19',
#         'display': 'Off Campus-Outpatient Hospital'}]}},
#     {'sequence': 3,
#      'diagnosisSequence': [2],
#      'category': {'coding': [{'system': 'https://bluebutton.cms.gov/resources/variables/line_cms_type_srvc_cd',
#         'code': '1',
#         'display': 'Medical care'}]},
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '713458007',
#         'display': 'Lack of access to transportation (finding)'}],
#       'text': 'Lack of access to transportation (finding)'},
#      'servicedPeriod': {'start': '1962-10-22T03:00:18+01:00',
#       'end': '1962-10-22T03:15:18+01:00'},
#      'locationCodeableConcept': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-serviceplace',
#         'code': '19',
#         'display': 'Off Campus-Outpatient Hospital'}]}}],
#    'total': [{'category': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/adjudication',
#         'code': 'submitted',
#         'display': 'Submitted Amount'}],
#       'text': 'Submitted Amount'},
#      'amount': {'value': 786.3299999999999, 'currency': 'USD'}}],
#    'payment': {'amount': {'value': 0.0, 'currency': 'USD'}}},
#   'request': {'method': 'POST', 'url': 'ExplanationOfBenefit'}},
#  {'fullUrl': 'urn:uuid:fdf63048-be7c-a402-a3c1-e3a4c18b11b8',
#   'resource': {'resourceType': 'Encounter',
#    'id': 'fdf63048-be7c-a402-a3c1-e3a4c18b11b8',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter']},
#    'identifier': [{'use': 'official',
#      'system': 'https://github.com/synthetichealth/synthea',
#      'value': 'fdf63048-be7c-a402-a3c1-e3a4c18b11b8'}],
#    'status': 'finished',
#    'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode',
#     'code': 'AMB'},
#    'type': [{'coding': [{'system': 'http://snomed.info/sct',
#        'code': '162673000',
#        'display': 'General examination of patient (procedure)'}],
#      'text': 'General examination of patient (procedure)'}],
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#     'display': 'Mr. Aaron697 Dickens475'},
#    'participant': [{'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-ParticipationType',
#          'code': 'PPRF',
#          'display': 'primary performer'}],
#        'text': 'primary performer'}],
#      'period': {'start': '1963-10-28T02:00:18+00:00',
#       'end': '1963-10-28T02:15:18+00:00'},
#      'individual': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#       'display': 'Dr. Wilmer32 Heidenreich818'}}],
#    'period': {'start': '1963-10-28T02:00:18+00:00',
#     'end': '1963-10-28T02:15:18+00:00'},
#    'location': [{'location': {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|08770baf-f5e6-3a1a-af4f-1d8be70df56f',
#       'display': 'MASS LUNG AND ALLERGY PC'}}],
#    'serviceProvider': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#     'display': 'MASS LUNG AND ALLERGY PC'}},
#   'request': {'method': 'POST', 'url': 'Encounter'}},
#  {'fullUrl': 'urn:uuid:bb2e0c13-7dbe-d38c-2849-94e87c1e8f7e',
#   'resource': {'resourceType': 'Condition',
#    'id': 'bb2e0c13-7dbe-d38c-2849-94e87c1e8f7e',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition']},
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#        'code': 'encounter-diagnosis',
#        'display': 'Encounter Diagnosis'}]}],
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '160903007',
#       'display': 'Full-time employment (finding)'}],
#     'text': 'Full-time employment (finding)'},
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'encounter': {'reference': 'urn:uuid:fdf63048-be7c-a402-a3c1-e3a4c18b11b8'},
#    'onsetDateTime': '1963-10-28T02:55:06+00:00',
#    'abatementDateTime': '1966-10-31T02:57:00+00:00',
#    'recordedDate': '1963-10-28T02:55:06+00:00'},
#   'request': {'method': 'POST', 'url': 'Condition'}},
#  {'fullUrl': 'urn:uuid:57b07326-cf70-bd80-9b0b-fc55c76a0146',
#   'resource': {'resourceType': 'Condition',
#    'id': '57b07326-cf70-bd80-9b0b-fc55c76a0146',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition']},
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#        'code': 'encounter-diagnosis',
#        'display': 'Encounter Diagnosis'}]}],
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '706893006',
#       'display': 'Victim of intimate partner abuse (finding)'}],
#     'text': 'Victim of intimate partner abuse (finding)'},
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'encounter': {'reference': 'urn:uuid:fdf63048-be7c-a402-a3c1-e3a4c18b11b8'},
#    'onsetDateTime': '1963-10-28T03:26:36+00:00',
#    'recordedDate': '1963-10-28T03:26:36+00:00'},
#   'request': {'method': 'POST', 'url': 'Condition'}},
#  {'fullUrl': 'urn:uuid:b606ad82-62ad-e89c-24db-0a03e7689340',
#   'resource': {'resourceType': 'DiagnosticReport',
#    'id': 'b606ad82-62ad-e89c-24db-0a03e7689340',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note']},
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://loinc.org',
#        'code': '34117-2',
#        'display': 'History and physical note'},
#       {'system': 'http://loinc.org',
#        'code': '51847-2',
#        'display': 'Evaluation+Plan note'}]}],
#    'code': {'coding': [{'system': 'http://loinc.org',
#       'code': '34117-2',
#       'display': 'History and physical note'},
#      {'system': 'http://loinc.org',
#       'code': '51847-2',
#       'display': 'Evaluation+Plan note'}]},
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'encounter': {'reference': 'urn:uuid:fdf63048-be7c-a402-a3c1-e3a4c18b11b8'},
#    'effectiveDateTime': '1963-10-28T02:00:18+00:00',
#    'issued': '1963-10-28T02:00:18.291+00:00',
#    'performer': [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#      'display': 'Dr. Wilmer32 Heidenreich818'}],
#    'presentedForm': [{'contentType': 'text/plain; charset=utf-8',
#      'data': '...'}]},
#   'request': {'method': 'POST', 'url': 'DiagnosticReport'}},
#  {'fullUrl': 'urn:uuid:5d4c98c8-eb1e-d753-e038-98230915cddd',
#   'resource': {'resourceType': 'DocumentReference',
#    'id': '5d4c98c8-eb1e-d753-e038-98230915cddd',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-documentreference']},
#    'identifier': [{'system': 'urn:ietf:rfc:3986',
#      'value': 'urn:uuid:b606ad82-62ad-e89c-24db-0a03e7689340'}],
#    'status': 'superseded',
#    'type': {'coding': [{'system': 'http://loinc.org',
#       'code': '34117-2',
#       'display': 'History and physical note'},
#      {'system': 'http://loinc.org',
#       'code': '51847-2',
#       'display': 'Evaluation+Plan note'}]},
#    'category': [{'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category',
#        'code': 'clinical-note',
#        'display': 'Clinical Note'}]}],
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'date': '1963-10-28T02:00:18.291+00:00',
#    'author': [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#      'display': 'Dr. Wilmer32 Heidenreich818'}],
#    'custodian': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'content': [{'attachment': {'contentType': 'text/plain; charset=utf-8',
#       'data': '...'},
#      'format': {'system': 'http://ihe.net/fhir/ValueSet/IHE.FormatCode.codesystem',
#       'code': 'urn:ihe:iti:xds:2017:mimeTypeSufficient',
#       'display': 'mimeType Sufficient'}}],
#    'context': {'encounter': [{'reference': 'urn:uuid:fdf63048-be7c-a402-a3c1-e3a4c18b11b8'}],
#     'period': {'start': '1963-10-28T02:00:18+00:00',
#      'end': '1963-10-28T02:15:18+00:00'}}},
#   'request': {'method': 'POST', 'url': 'DocumentReference'}},
#  {'fullUrl': 'urn:uuid:5f62137b-7644-64f5-f54b-6b516d7a3191',
#   'resource': {'resourceType': 'Claim',
#    'id': '5f62137b-7644-64f5-f54b-6b516d7a3191',
#    'status': 'active',
#    'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/claim-type',
#       'code': 'institutional'}]},
#    'use': 'claim',
#    'patient': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#     'display': 'Aaron697 Dickens475'},
#    'billablePeriod': {'start': '1963-10-28T02:00:18+00:00',
#     'end': '1963-10-28T02:15:18+00:00'},
#    'created': '1963-10-28T02:15:18+00:00',
#    'provider': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'priority': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/processpriority',
#       'code': 'normal'}]},
#    'facility': {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|08770baf-f5e6-3a1a-af4f-1d8be70df56f',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'diagnosis': [{'sequence': 1,
#      'diagnosisReference': {'reference': 'urn:uuid:bb2e0c13-7dbe-d38c-2849-94e87c1e8f7e'}},
#     {'sequence': 2,
#      'diagnosisReference': {'reference': 'urn:uuid:57b07326-cf70-bd80-9b0b-fc55c76a0146'}}],
#    'insurance': [{'sequence': 1,
#      'focal': True,
#      'coverage': {'display': 'NO_INSURANCE'}}],
#    'item': [{'sequence': 1,
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '162673000',
#         'display': 'General examination of patient (procedure)'}],
#       'text': 'General examination of patient (procedure)'},
#      'encounter': [{'reference': 'urn:uuid:fdf63048-be7c-a402-a3c1-e3a4c18b11b8'}]},
#     {'sequence': 2,
#      'diagnosisSequence': [1],
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '160903007',
#         'display': 'Full-time employment (finding)'}],
#       'text': 'Full-time employment (finding)'}},
#     {'sequence': 3,
#      'diagnosisSequence': [2],
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '706893006',
#         'display': 'Victim of intimate partner abuse (finding)'}],
#       'text': 'Victim of intimate partner abuse (finding)'}}],
#    'total': {'value': 786.3299999999999, 'currency': 'USD'}},
#   'request': {'method': 'POST', 'url': 'Claim'}},
#  {'fullUrl': 'urn:uuid:91eb6769-cb39-510d-7ab3-642ad4ff4ada',
#   'resource': {'resourceType': 'ExplanationOfBenefit',
#    'id': '91eb6769-cb39-510d-7ab3-642ad4ff4ada',
#    'contained': [{'resourceType': 'ServiceRequest',
#      'id': 'referral',
#      'status': 'completed',
#      'intent': 'order',
#      'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#      'requester': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519'},
#      'performer': [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519'}]},
#     {'resourceType': 'Coverage',
#      'id': 'coverage',
#      'status': 'active',
#      'type': {'text': 'NO_INSURANCE'},
#      'beneficiary': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#      'payor': [{'display': 'NO_INSURANCE'}]}],
#    'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#      'value': '5f62137b-7644-64f5-f54b-6b516d7a3191'},
#     {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#      'value': '99999999999'}],
#    'status': 'active',
#    'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/claim-type',
#       'code': 'institutional'}]},
#    'use': 'claim',
#    'patient': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'billablePeriod': {'start': '1963-10-28T02:15:18+00:00',
#     'end': '1964-10-28T02:15:18+00:00'},
#    'created': '1963-10-28T02:15:18+00:00',
#    'insurer': {'display': 'NO_INSURANCE'},
#    'provider': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519'},
#    'referral': {'reference': '#referral'},
#    'facility': {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|08770baf-f5e6-3a1a-af4f-1d8be70df56f',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'claim': {'reference': 'urn:uuid:5f62137b-7644-64f5-f54b-6b516d7a3191'},
#    'outcome': 'complete',
#    'careTeam': [{'sequence': 1,
#      'provider': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519'},
#      'role': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/claimcareteamrole',
#         'code': 'primary',
#         'display': 'Primary Care Practitioner'}]}}],
#    'diagnosis': [{'sequence': 1,
#      'diagnosisReference': {'reference': 'urn:uuid:bb2e0c13-7dbe-d38c-2849-94e87c1e8f7e'},
#      'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-diagnosistype',
#          'code': 'principal'}]}]},
#     {'sequence': 2,
#      'diagnosisReference': {'reference': 'urn:uuid:57b07326-cf70-bd80-9b0b-fc55c76a0146'},
#      'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-diagnosistype',
#          'code': 'principal'}]}]}],
#    'insurance': [{'focal': True,
#      'coverage': {'reference': '#coverage', 'display': 'NO_INSURANCE'}}],
#    'item': [{'sequence': 1,
#      'category': {'coding': [{'system': 'https://bluebutton.cms.gov/resources/variables/line_cms_type_srvc_cd',
#         'code': '1',
#         'display': 'Medical care'}]},
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '162673000',
#         'display': 'General examination of patient (procedure)'}],
#       'text': 'General examination of patient (procedure)'},
#      'servicedPeriod': {'start': '1963-10-28T02:00:18+00:00',
#       'end': '1963-10-28T02:15:18+00:00'},
#      'locationCodeableConcept': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-serviceplace',
#         'code': '19',
#         'display': 'Off Campus-Outpatient Hospital'}]},
#      'encounter': [{'reference': 'urn:uuid:fdf63048-be7c-a402-a3c1-e3a4c18b11b8'}]},
#     {'sequence': 2,
#      'diagnosisSequence': [1],
#      'category': {'coding': [{'system': 'https://bluebutton.cms.gov/resources/variables/line_cms_type_srvc_cd',
#         'code': '1',
#         'display': 'Medical care'}]},
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '160903007',
#         'display': 'Full-time employment (finding)'}],
#       'text': 'Full-time employment (finding)'},
#      'servicedPeriod': {'start': '1963-10-28T02:00:18+00:00',
#       'end': '1963-10-28T02:15:18+00:00'},
#      'locationCodeableConcept': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-serviceplace',
#         'code': '19',
#         'display': 'Off Campus-Outpatient Hospital'}]}},
#     {'sequence': 3,
#      'diagnosisSequence': [2],
#      'category': {'coding': [{'system': 'https://bluebutton.cms.gov/resources/variables/line_cms_type_srvc_cd',
#         'code': '1',
#         'display': 'Medical care'}]},
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '706893006',
#         'display': 'Victim of intimate partner abuse (finding)'}],
#       'text': 'Victim of intimate partner abuse (finding)'},
#      'servicedPeriod': {'start': '1963-10-28T02:00:18+00:00',
#       'end': '1963-10-28T02:15:18+00:00'},
#      'locationCodeableConcept': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-serviceplace',
#         'code': '19',
#         'display': 'Off Campus-Outpatient Hospital'}]}}],
#    'total': [{'category': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/adjudication',
#         'code': 'submitted',
#         'display': 'Submitted Amount'}],
#       'text': 'Submitted Amount'},
#      'amount': {'value': 786.3299999999999, 'currency': 'USD'}}],
#    'payment': {'amount': {'value': 0.0, 'currency': 'USD'}}},
#   'request': {'method': 'POST', 'url': 'ExplanationOfBenefit'}},
#  {'fullUrl': 'urn:uuid:b6c96767-0a76-9d09-7376-b62620228281',
#   'resource': {'resourceType': 'Encounter',
#    'id': 'b6c96767-0a76-9d09-7376-b62620228281',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter']},
#    'identifier': [{'use': 'official',
#      'system': 'https://github.com/synthetichealth/synthea',
#      'value': 'b6c96767-0a76-9d09-7376-b62620228281'}],
#    'status': 'finished',
#    'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode',
#     'code': 'AMB'},
#    'type': [{'coding': [{'system': 'http://snomed.info/sct',
#        'code': '162673000',
#        'display': 'General examination of patient (procedure)'}],
#      'text': 'General examination of patient (procedure)'}],
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#     'display': 'Mr. Aaron697 Dickens475'},
#    'participant': [{'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-ParticipationType',
#          'code': 'PPRF',
#          'display': 'primary performer'}],
#        'text': 'primary performer'}],
#      'period': {'start': '1966-10-31T02:00:18+00:00',
#       'end': '1966-10-31T02:15:18+00:00'},
#      'individual': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#       'display': 'Dr. Wilmer32 Heidenreich818'}}],
#    'period': {'start': '1966-10-31T02:00:18+00:00',
#     'end': '1966-10-31T02:15:18+00:00'},
#    'location': [{'location': {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|08770baf-f5e6-3a1a-af4f-1d8be70df56f',
#       'display': 'MASS LUNG AND ALLERGY PC'}}],
#    'serviceProvider': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#     'display': 'MASS LUNG AND ALLERGY PC'}},
#   'request': {'method': 'POST', 'url': 'Encounter'}},
#  {'fullUrl': 'urn:uuid:8609343c-7ccd-a020-ab8b-379ebe4e2e20',
#   'resource': {'resourceType': 'Condition',
#    'id': '8609343c-7ccd-a020-ab8b-379ebe4e2e20',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition']},
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#        'code': 'encounter-diagnosis',
#        'display': 'Encounter Diagnosis'}]}],
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '266934004',
#       'display': 'Transport problems (finding)'}],
#     'text': 'Transport problems (finding)'},
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'encounter': {'reference': 'urn:uuid:b6c96767-0a76-9d09-7376-b62620228281'},
#    'onsetDateTime': '1966-10-31T02:57:00+00:00',
#    'recordedDate': '1966-10-31T02:57:00+00:00'},
#   'request': {'method': 'POST', 'url': 'Condition'}},
#  {'fullUrl': 'urn:uuid:96d6dcdd-8694-f570-611c-1f2eca14a4e3',
#   'resource': {'resourceType': 'Condition',
#    'id': '96d6dcdd-8694-f570-611c-1f2eca14a4e3',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition']},
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#        'code': 'encounter-diagnosis',
#        'display': 'Encounter Diagnosis'}]}],
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '422650009',
#       'display': 'Social isolation (finding)'}],
#     'text': 'Social isolation (finding)'},
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'encounter': {'reference': 'urn:uuid:b6c96767-0a76-9d09-7376-b62620228281'},
#    'onsetDateTime': '1966-10-31T02:57:00+00:00',
#    'abatementDateTime': '1997-09-15T03:37:18+01:00',
#    'recordedDate': '1966-10-31T02:57:00+00:00'},
#   'request': {'method': 'POST', 'url': 'Condition'}},
#  {'fullUrl': 'urn:uuid:95fd4de3-2433-a866-f9dd-c24383815c92',
#   'resource': {'resourceType': 'Condition',
#    'id': '95fd4de3-2433-a866-f9dd-c24383815c92',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition']},
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#        'code': 'encounter-diagnosis',
#        'display': 'Encounter Diagnosis'}]}],
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '266948004',
#       'display': 'Has a criminal record (finding)'}],
#     'text': 'Has a criminal record (finding)'},
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'encounter': {'reference': 'urn:uuid:b6c96767-0a76-9d09-7376-b62620228281'},
#    'onsetDateTime': '1966-10-31T02:57:00+00:00',
#    'recordedDate': '1966-10-31T02:57:00+00:00'},
#   'request': {'method': 'POST', 'url': 'Condition'}},
#  {'fullUrl': 'urn:uuid:72314430-f208-4362-aec6-28ed61f052ce',
#   'resource': {'resourceType': 'DiagnosticReport',
#    'id': '72314430-f208-4362-aec6-28ed61f052ce',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note']},
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://loinc.org',
#        'code': '34117-2',
#        'display': 'History and physical note'},
#       {'system': 'http://loinc.org',
#        'code': '51847-2',
#        'display': 'Evaluation+Plan note'}]}],
#    'code': {'coding': [{'system': 'http://loinc.org',
#       'code': '34117-2',
#       'display': 'History and physical note'},
#      {'system': 'http://loinc.org',
#       'code': '51847-2',
#       'display': 'Evaluation+Plan note'}]},
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'encounter': {'reference': 'urn:uuid:b6c96767-0a76-9d09-7376-b62620228281'},
#    'effectiveDateTime': '1966-10-31T02:00:18+00:00',
#    'issued': '1966-10-31T02:00:18.291+00:00',
#    'performer': [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#      'display': 'Dr. Wilmer32 Heidenreich818'}],
#    'presentedForm': [{'contentType': 'text/plain; charset=utf-8',
#      'data': '...'}]},
#   'request': {'method': 'POST', 'url': 'DiagnosticReport'}},
#  {'fullUrl': 'urn:uuid:800c36f7-315f-a499-669a-8af3e71c469a',
#   'resource': {'resourceType': 'DocumentReference',
#    'id': '800c36f7-315f-a499-669a-8af3e71c469a',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-documentreference']},
#    'identifier': [{'system': 'urn:ietf:rfc:3986',
#      'value': 'urn:uuid:72314430-f208-4362-aec6-28ed61f052ce'}],
#    'status': 'superseded',
#    'type': {'coding': [{'system': 'http://loinc.org',
#       'code': '34117-2',
#       'display': 'History and physical note'},
#      {'system': 'http://loinc.org',
#       'code': '51847-2',
#       'display': 'Evaluation+Plan note'}]},
#    'category': [{'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category',
#        'code': 'clinical-note',
#        'display': 'Clinical Note'}]}],
#    'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    'date': '1966-10-31T02:00:18.291+00:00',
#    'author': [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#      'display': 'Dr. Wilmer32 Heidenreich818'}],
#    'custodian': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'content': [{'attachment': {'contentType': 'text/plain; charset=utf-8',
#       'data': '...'},
#      'format': {'system': 'http://ihe.net/fhir/ValueSet/IHE.FormatCode.codesystem',
#       'code': 'urn:ihe:iti:xds:2017:mimeTypeSufficient',
#       'display': 'mimeType Sufficient'}}],
#    'context': {'encounter': [{'reference': 'urn:uuid:b6c96767-0a76-9d09-7376-b62620228281'}],
#     'period': {'start': '1966-10-31T02:00:18+00:00',
#      'end': '1966-10-31T02:15:18+00:00'}}},
#   'request': {'method': 'POST', 'url': 'DocumentReference'}},
#  {'fullUrl': 'urn:uuid:9c776ce1-4909-bd3d-862f-0a312918861d',
#   'resource': {'resourceType': 'Claim',
#    'id': '9c776ce1-4909-bd3d-862f-0a312918861d',
#    'status': 'active',
#    'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/claim-type',
#       'code': 'institutional'}]},
#    'use': 'claim',
#    'patient': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#     'display': 'Aaron697 Dickens475'},
#    'billablePeriod': {'start': '1966-10-31T02:00:18+00:00',
#     'end': '1966-10-31T02:15:18+00:00'},
#    'created': '1966-10-31T02:15:18+00:00',
#    'provider': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'priority': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/processpriority',
#       'code': 'normal'}]},
#    'facility': {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|08770baf-f5e6-3a1a-af4f-1d8be70df56f',
#     'display': 'MASS LUNG AND ALLERGY PC'},
#    'diagnosis': [{'sequence': 1,
#      'diagnosisReference': {'reference': 'urn:uuid:8609343c-7ccd-a020-ab8b-379ebe4e2e20'}},
#     {'sequence': 2,
#      'diagnosisReference': {'reference': 'urn:uuid:96d6dcdd-8694-f570-611c-1f2eca14a4e3'}},
#     {'sequence': 3,
#      'diagnosisReference': {'reference': 'urn:uuid:95fd4de3-2433-a866-f9dd-c24383815c92'}}],
#    'insurance': [{'sequence': 1,
#      'focal': True,
#      'coverage': {'display': 'NO_INSURANCE'}}],
#    'item': [{'sequence': 1,
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '162673000',
#         'display': 'General examination of patient (procedure)'}],
#       'text': 'General examination of patient (procedure)'},
#      'encounter': [{'reference': 'urn:uuid:b6c96767-0a76-9d09-7376-b62620228281'}]},
#     {'sequence': 2,
#      'diagnosisSequence': [1],
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '266934004',
#         'display': 'Transport problems (finding)'}],
#       'text': 'Transport problems (finding)'}},
#     {'sequence': 3,
#      'diagnosisSequence': [2],
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '422650009',
#         'display': 'Social isolation (finding)'}],
#       'text': 'Social isolation (finding)'}},
#     {'sequence': 4,
#      'diagnosisSequence': [3],
#      'productOrService': {'coding': [{'system': 'http://snomed.info/sct',
#         'code': '266948004',
#         'display': 'Has a criminal record (finding)'}],
#       'text': 'Has a criminal record (finding)'}}],
#    'total': {'value': 786.3299999999999, 'currency': 'USD'}},
#   'request': {'method': 'POST', 'url': 'Claim'}},
#  {'fullUrl': 'urn:uuid:0396b087-1858-9edc-7d37-3e1d28f354a5',
#   'resource': {'resourceType': 'ExplanationOfBenefit',
#    'id': '0396b087-1858-9edc-7d37-3e1d28f354a5',
#    'contained': [{'resourceType': 'ServiceRequest',
#      'id': 'referral',
#      'status': 'completed',
#      'intent': 'order',
#      'subject': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#      'requester': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519'},
#      'performer': [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519'}]},
#     {'resourceType': 'Coverage',
#      'id': 'coverage',
#      'status': 'active',
#      'type': {'text': 'NO_INSURANCE'},
#      'beneficiary': {'reference': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#      'payor': [{'display': 'NO_INSURANCE'}]}],
#    'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#      'value': '9c776ce1-4909-bd3d-862f-0a312918861d'},
#     {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#      'value': '99999999999'}],
#    'status': 'active',
#    'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem
#     {'reference': 'urn:uuid:44511032-38d9-8c8e-b0a6-4ce268d87c8d'},
#     {'reference': 'urn:uuid:9b763fa9-223c-44ac-9396-46fadf5d9d2a'},
#     {'reference': 'urn:uuid:3789dab9-03a9-fe76-5146-9791e5790921'},
#     {'reference': 'urn:uuid:d9bac9ec-28df-b776-f9f5-785a0cdb8c16'},
#     {'reference': 'urn:uuid:5b6740e4-c5d6-e34d-b56e-01b4437768f2'},
#     {'reference': 'urn:uuid:115f8cd8-2aa3-8b1b-10ff-6042dc5521e6'},
#     {'reference': 'urn:uuid:95e2d63a-840a-7f24-eb39-4fbf589e3caf'},
#     {'reference': 'urn:uuid:f539c9bd-2616-7eaf-b574-ef0a17d9871b'},
#     {'reference': 'urn:uuid:7e9e5c76-b0fd-7a31-540e-417f8c089fcb'},
#     {'reference': 'urn:uuid:8a5f1f60-b215-53ab-9fa3-f192430ec739'},
#     {'reference': 'urn:uuid:021fd605-b4a9-c14f-e0f8-289676c53cfc'},
#     {'reference': 'urn:uuid:f800447a-ef7b-3669-1f66-8fd6d0a1ad4b'},
#     {'reference': 'urn:uuid:e88d688c-e5c8-f67d-9c90-cef3591772bf'},
#     {'reference': 'urn:uuid:a0f09238-dc46-b6ab-d024-1b65de24b05c'},
#     {'reference': 'urn:uuid:22130f5f-fd80-715b-e9af-ad61740887d1'},
#     {'reference': 'urn:uuid:21a45eba-6c35-5015-a5ad-2ddf8f2feffe'},
#     {'reference': 'urn:uuid:165c1e0b-675c-cfb0-cb59-71fadb3aefb7'}],
#    'recorded': '1998-08-17T03:00:18.291+01:00',
#    'agent': [{'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/provenance-participant-type',
#         'code': 'author',
#         'display': 'Author'}],
#       'text': 'Author'},
#      'who': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#       'display': 'Dr. Wilmer32 Heidenreich818'},
#      'onBehalfOf': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#       'display': 'MASS LUNG AND ALLERGY PC'}},
#     {'type': {'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/us-core-provenance-participant-type',
#         'code': 'transmitter',
#         'display': 'Transmitter'}],
#       'text': 'Transmitter'},
#      'who': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999914519',
#       'display': 'Dr. Wilmer32 Heidenreich818'},
#      'onBehalfOf': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|3f44c95d-aa3d-3385-93f7-9b0bdecc52a6',
#       'display': 'MASS LUNG AND ALLERGY PC'}}]},
#   'request': {'method': 'POST', 'url': 'Provenance'}}]

# %%
resources
# Out:
# [{'fullUrl': 'urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#   'resource': {'resourceType': 'Patient',
#    'id': '8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#    'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#    'text': {'status': 'generated',
#     'div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: master-branch-latest\n .   Person seed: 8886041252665297312  Population seed: 13235</div>'},
#    'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#      'extension': [{'url': 'ombCategory',
#        'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#         'code': '2106-3',
#         'display': 'White'}},
#       {'url': 'text', 'valueString': 'White'}]},
#     {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#      'extension': [{'url': 'ombCategory',
#        'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#         'code': '2186-5',
#         'display': 'Not Hispanic or Latino'}},
#       {'url': 'text', 'valueString': 'Not Hispanic or Latino'}]},
#     {'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName',
#      'valueString': 'Holley125 Champlin946'},
#     {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex',
#      'valueCode': 'M'},
#     {'url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace',
#      'valueAddress': {'city': 'Barnstable',
#       'state': 'Massachusetts',
#       'country': 'US'}},
#     {'url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years',
#      'valueDecimal': 0.05826471038258488},
#     {'url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years',
#      'valueDecimal': 52.94173528961741}],
#    'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#      'value': '8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR',
#         'display': 'Medical Record Number'}],
#       'text': 'Medical Record Number'},
#      'system': 'http://hospital.smarthealthit.org',
#      'value': '8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'SS',
#         'display': 'Social Security Number'}],
#       'text': 'Social Security Number'},
#      'system': 'http://hl7.org/fhir/sid/us-ssn',
#      'value': '999-86-2571'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'DL',
#         'display': "Driver's License"}],
#       'text': "Driver's License"},
#      'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#      'value': 'S99949530'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'PPN',
#         'display': 'Passport Number'}],
#       'text': 'Passport Number'},
#      'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#      'value': 'X67249552X'}],
#    'name': [{'use': 'official',
#      'family': 'Dickens475',
#      'given': ['Aaron697'],
#      'prefix': ['Mr.']}],
#    'telecom': [{'system': 'phone', 'value': '555-152-6034', 'use': 'home'}],
#    'gender': 'male',
#    'birthDate': '1944-08-28',
#    'deceasedDateTime': '1998-08-15T13:05:53+01:00',
#    'address': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/geolocation',
#        'extension': [{'url': 'latitude', 'valueDecimal': 42.13509612101196},
#         {'url': 'longitude', 'valueDecimal': -71.94977170576706}]}],
#      'line': ['859 Altenwerth Run Unit 88'],
#      'city': 'Charlton',
#      'state': 'MA',
#      'country': 'US'}],
#    'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus',
#       'code': 'M',
#       'display': 'M'}],
#     'text': 'M'},
#    'multipleBirthBoolean': False,
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English'}],
#       'text': 'English'}}]},
#   'request': {'method': 'POST', 'url': 'Patient'}}]
